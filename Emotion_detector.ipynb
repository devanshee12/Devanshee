# %% [markdown]
# <a href="https://colab.research.google.com/github/devanshee12/Devanshee/blob/main/Emotion_detector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install deepface
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 7.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 kB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 47.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 50.2 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114249 sha256=e43f37d9044cb910c0112c14e8884934e2cce5feb5d48e6bec882ebedf0f2f30
#   Stored in directory: /root/.cache/pip/wheels/46/54/24/1624fd5b8674eb1188623f7e8e17cdf7c0f6c24b609dfb8a89
# Successfully built fire
# ...

# %%
from google.colab import files
uploaded = files.upload()
photo_path = list(uploaded.keys())[0]  # Gets your uploaded file
# Out:
#      <input type="file" id="files-13f277c8-be9f-4800-8832-1468b6726ebe" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-13f277c8-be9f-4800-8832-1468b6726ebe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import cv2
from deepface import DeepFace
from google.colab.patches import cv2_imshow

# Upload image
from google.colab import files
uploaded = files.upload()
photo_path = list(uploaded.keys())[0]

# Analyze emotion
result = DeepFace.analyze(img_path=photo_path, actions=['emotion'])
dominant_emotion = result[0]['dominant_emotion']

# Draw the result on the image
img = cv2.imread(photo_path)
cv2.putText(img, f"Emotion: {dominant_emotion}", (50, 50),
            cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

# Show result
cv2_imshow(img)
print("Detected Emotion:", dominant_emotion)
# Out:
# 25-04-07 17:37:47 - Directory /root/.deepface has been created
# 25-04-07 17:37:47 - Directory /root/.deepface/weights has been created
#      <input type="file" id="files-642d6cab-2665-4dd3-8ece-1294a1be7d36" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-642d6cab-2665-4dd3-8ece-1294a1be7d36">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# ...
